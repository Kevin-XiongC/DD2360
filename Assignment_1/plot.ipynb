# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# dd=pd.read_fwf('.\device-device.txt',sep=" ")
# dh=pd.read_fwf('.\device-host.txt',sep=" ")
# hd=pd.read_fwf('.\host-device.txt',sep=" ")

# %%
a = np.zeros(1022)+np.random.normal(0,1,1022)
plt.plot(a)
plt.show()
